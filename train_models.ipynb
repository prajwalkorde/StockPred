# %%
import os
import warnings
import numpy as np
import pandas as pd
import configparser
warnings.filterwarnings("ignore")
from utils import nifty50_companies
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

config = configparser.ConfigParser()
config.read("config.ini")

no_of_epochs = int(config['model']['no_of_epochs'])
batch_size = int(config['model']['batch_size'])

def preprocess_data(data):
    # Ensure 'Close' column exists and is numeric
    if 'Close' not in data.columns:
        raise ValueError("Missing 'Close' column in data.")
    
    # Convert 'Close' column to numeric (will convert invalid strings to NaN)
    data['Close'] = pd.to_numeric(data['Close'], errors='coerce')
    
    # Drop any rows with NaN values in 'Close'
    data = data.dropna(subset=['Close'])

    # Check again if data is now empty
    if data.empty:
        raise ValueError("No valid numeric data in 'Close' column after cleaning.")

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data['Close'].values.reshape(-1, 1))
    return scaled_data, scaler

def build_lstm_model(X, Y):
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(X.shape[1], 1)))
    model.add(LSTM(50, return_sequences=False))
    model.add(Dense(25))
    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    model.fit(X, Y, batch_size = batch_size, epochs = no_of_epochs)

    return model

def train_and_save_models():
    for company, ticker in nifty50_companies.items():
        filename = f"data/{ticker}.csv"
        model_filename = f"models/{ticker}_model.keras"
        
        # Check if data file exists
        if os.path.exists(filename):
            # Load data
            print(f"Training started for {company}.. Please wait..!!")
            # data = pd.read_csv(filename, index_col='Date', parse_dates=True)
            df = pd.read_csv(filename)
            if 'Date' not in df.columns:
              print(f"Skipping {company} — 'Date' column missing.")
              continue

            df['Date'] = pd.to_datetime(df['Date'])
            df.set_index('Date', inplace=True)
            data = df

            scaled_data, scaler = preprocess_data(data)
            
            # Prepare dataset
            X, Y = [], []
            for i in range(len(scaled_data) - 100 - 1):
                X.append(scaled_data[i:(i + 100), 0])
                Y.append(scaled_data[i + 100, 0])
            X, Y = np.array(X), np.array(Y)
            X = X.reshape(X.shape[0], X.shape[1], 1)
            
            # Build and train model
            model = build_lstm_model(X, Y)
            
            # Save model
            model.save(model_filename)
            print(f"Saved model for {company} as {model_filename}.")
            print("-----------------------------------------------")
        else:
            print(f"No data file found for {company}.")
    
train_and_save_models()
# Out:
# Training started for Adani Enterprises.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 24s 104ms/step - loss: 0.0062
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - loss: 3.7399e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 2.8995e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - loss: 2.6794e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - loss: 2.4311e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - loss: 2.0705e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - loss: 1.8250e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - loss: 1.8019e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 31s 176ms/step - loss: 1.4017e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 1.1954e-04
# Saved model for Adani Enterprises as models/ADANIENT.NS_model.keras.
# -----------------------------------------------
# Training started for Asian Paints.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - loss: 0.0116
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 2.3064e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - loss: 2.3243e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - loss: 2.2969e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 2.1279e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - loss: 2.1847e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - loss: 1.7203e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - loss: 1.6546e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.5847e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 1.4765e-04
# Saved model for Asian Paints as models/ASIANPAINT.NS_model.keras.
# -----------------------------------------------
# Training started for Axis Bank.. Please wait..!!
# Epoch 1/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 23s 89ms/step - loss: 0.0172
# Epoch 2/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: 2.5855e-04
# Epoch 3/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: 2.5054e-04
# Epoch 4/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: 2.4617e-04
# Epoch 5/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - loss: 2.0104e-04
# Epoch 6/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - loss: 2.0923e-04
# Epoch 7/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 89ms/step - loss: 1.7178e-04
# Epoch 8/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - loss: 1.5579e-04
# Epoch 9/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - loss: 1.3741e-04
# Epoch 10/10
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 18s 88ms/step - loss: 1.2288e-04
# Saved model for Axis Bank as models/AXISBANK.NS_model.keras.
# -----------------------------------------------
# Training started for Bajaj Finance.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 87ms/step - loss: 0.0097
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - loss: 2.6924e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - loss: 2.3146e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - loss: 2.8203e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 2.1317e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - loss: 2.5073e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - loss: 1.8635e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 2.2100e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - loss: 1.9482e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - loss: 1.6208e-04
# Saved model for Bajaj Finance as models/BAJFINANCE.NS_model.keras.
# -----------------------------------------------
# Training started for Bharat Petroleum.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0050
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.6503e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 87ms/step - loss: 1.7484e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 87ms/step - loss: 1.3804e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2801e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.3669e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.3296e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.0925e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.1357e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2442e-04
# Saved model for Bharat Petroleum as models/BPCL.NS_model.keras.
# -----------------------------------------------
# Training started for Bharti Airtel.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 87ms/step - loss: 0.0105
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.4353e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.2649e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 1.3203e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - loss: 1.1002e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 87ms/step - loss: 1.0917e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 1.3541e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 1.0773e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - loss: 9.8867e-05
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - loss: 1.0703e-04
# Saved model for Bharti Airtel as models/BHARTIARTL.NS_model.keras.
# -----------------------------------------------
# Training started for Britannia.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - loss: 0.0081
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.3218e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.1820e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.3071e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 9.5825e-05
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.2983e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.1081e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 8.9174e-05
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 7.6328e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 8.4472e-05
# Saved model for Britannia as models/BRITANNIA.NS_model.keras.
# -----------------------------------------------
# Training started for Cipla.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - loss: 0.0060
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.4394e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.7720e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.1372e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.0097e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.1843e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 87ms/step - loss: 9.5305e-05
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.3188e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 8.5577e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 7.6560e-05
# Saved model for Cipla as models/CIPLA.NS_model.keras.
# -----------------------------------------------
# Training started for Coal India.. Please wait..!!
# Epoch 1/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - loss: 0.0123
# Epoch 2/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - loss: 3.2976e-04
# Epoch 3/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 3.0193e-04
# Epoch 4/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - loss: 3.3023e-04
# Epoch 5/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 2.7856e-04
# Epoch 6/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 3.7864e-04
# Epoch 7/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - loss: 2.4981e-04
# Epoch 8/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - loss: 2.4565e-04
# Epoch 9/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 3.0755e-04
# Epoch 10/10
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - loss: 2.5532e-04
# Saved model for Coal India as models/COALINDIA.NS_model.keras.
# -----------------------------------------------
# Training started for Divi's Laboratories.. Please wait..!!
# Epoch 1/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 17s 77ms/step - loss: 0.0100
# Epoch 2/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 2.2298e-04
# Epoch 3/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - loss: 1.8439e-04
# Epoch 4/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 1.6819e-04
# Epoch 5/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - loss: 2.4702e-04
# Epoch 6/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 1.4729e-04
# Epoch 7/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 78ms/step - loss: 1.8985e-04
# Epoch 8/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - loss: 1.3455e-04
# Epoch 9/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 1.2724e-04
# Epoch 10/10
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 1.5558e-04
# Saved model for Divi's Laboratories as models/DIVISLAB.NS_model.keras.
# -----------------------------------------------
# Training started for Dr. Reddy's Laboratories.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.0062
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 2.2698e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.9782e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.7781e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.6247e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.9852e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.2664e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.4013e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.2945e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.1646e-04
# Saved model for Dr. Reddy's Laboratories as models/DRREDDY.NS_model.keras.
# -----------------------------------------------
# Training started for Eicher Motors.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - loss: 0.0093
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.7582e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.6739e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.5765e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - loss: 1.5477e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.4568e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.5069e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.4111e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.2639e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.0222e-04
# Saved model for Eicher Motors as models/EICHERMOT.NS_model.keras.
# -----------------------------------------------
# Training started for Grasim Industries.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 0.0091
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - loss: 2.2951e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 2.1593e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 1.9609e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 1.9998e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 1.9675e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 1.4365e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.5666e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 1.3363e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - loss: 1.3773e-04
# Saved model for Grasim Industries as models/GRASIM.NS_model.keras.
# -----------------------------------------------
# Training started for HCL Technologies.. Please wait..!!
# Epoch 1/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 0.0142
# Epoch 2/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2913e-04
# Epoch 3/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.1317e-04
# Epoch 4/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.3781e-04
# Epoch 5/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.0979e-04
# Epoch 6/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.2948e-04
# Epoch 7/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.0733e-04
# Epoch 8/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 9.8994e-05
# Epoch 9/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 8.4177e-05
# Epoch 10/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 9.4191e-05
# Saved model for HCL Technologies as models/HCLTECH.NS_model.keras.
# -----------------------------------------------
# Training started for HDFC Bank.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 90ms/step - loss: 0.0136
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.6561e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.7184e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.8633e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.6973e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.4288e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.4846e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.4640e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2341e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2395e-04
# Saved model for HDFC Bank as models/HDFCBANK.NS_model.keras.
# -----------------------------------------------
# Training started for Hero MotoCorp.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 0.0127
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 2.0470e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 2.1724e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.9604e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.7422e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.4022e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.6012e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.2613e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.3275e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.1235e-04
# Saved model for Hero MotoCorp as models/HEROMOTOCO.NS_model.keras.
# -----------------------------------------------
# Training started for Hindalco.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0054
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 2.6689e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 2.4640e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 2.2978e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.9063e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.6808e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.5723e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.2303e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2516e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.2056e-04
# Saved model for Hindalco as models/HINDALCO.NS_model.keras.
# -----------------------------------------------
# Training started for Hindustan Unilever.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0115
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.4996e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.6013e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.5248e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.1813e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - loss: 1.1343e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.0515e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.0746e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.0589e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 9.9288e-05
# Saved model for Hindustan Unilever as models/HINDUNILVR.NS_model.keras.
# -----------------------------------------------
# Training started for ICICI Bank.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 22s 93ms/step - loss: 0.0087
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - loss: 1.2925e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.3650e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.2722e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.2136e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.1912e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.2282e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.2329e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.0749e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.0585e-04
# Saved model for ICICI Bank as models/ICICIBANK.NS_model.keras.
# -----------------------------------------------
# Training started for IndusInd Bank.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 0.0166
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 4.9437e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 3.9239e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 3.3733e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 3.2308e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 2.7349e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 2.3294e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 2.6249e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 2.1098e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.9594e-04
# Saved model for IndusInd Bank as models/INDUSINDBK.NS_model.keras.
# -----------------------------------------------
# Training started for Infosys.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 90ms/step - loss: 0.0101
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.6393e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - loss: 1.4743e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 23s 100ms/step - loss: 1.5158e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.7473e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.2256e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - loss: 1.1906e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.1436e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.1940e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.0419e-04
# Saved model for Infosys as models/INFY.NS_model.keras.
# -----------------------------------------------
# Training started for ITC.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0079
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.3170e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.2020e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.1331e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 9.4381e-05
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.0375e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.0001e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.0843e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 8.2327e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 9.0450e-05
# Saved model for ITC as models/ITC.NS_model.keras.
# -----------------------------------------------
# Training started for JSW Steel.. Please wait..!!
# Epoch 1/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - loss: 0.0057
# Epoch 2/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 2.0166e-04
# Epoch 3/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - loss: 1.9930e-04
# Epoch 4/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - loss: 2.0849e-04
# Epoch 5/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.6097e-04
# Epoch 6/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.4844e-04
# Epoch 7/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - loss: 1.7739e-04
# Epoch 8/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.7310e-04
# Epoch 9/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.1547e-04
# Epoch 10/10
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.2928e-04
# Saved model for JSW Steel as models/JSWSTEEL.NS_model.keras.
# -----------------------------------------------
# Training started for Kotak Mahindra Bank.. Please wait..!!
# Epoch 1/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 22s 91ms/step - loss: 0.0190
# Epoch 2/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - loss: 2.6226e-04
# Epoch 3/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - loss: 2.9221e-04
# Epoch 4/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 2.2704e-04
# Epoch 5/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - loss: 2.5070e-04
# Epoch 6/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - loss: 2.3634e-04
# Epoch 7/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - loss: 1.9669e-04
# Epoch 8/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - loss: 1.9748e-04
# Epoch 9/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - loss: 1.7965e-04
# Epoch 10/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 17s 91ms/step - loss: 1.9749e-04
# Saved model for Kotak Mahindra Bank as models/KOTAKBANK.NS_model.keras.
# -----------------------------------------------
# Training started for Larsen & Toubro.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 0.0057
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.8699e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.5931e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 1.7173e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - loss: 1.6476e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.5449e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.4275e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.3288e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.3110e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 1.1785e-04
# Saved model for Larsen & Toubro as models/LT.NS_model.keras.
# -----------------------------------------------
# Training started for Mahindra & Mahindra.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0077
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.4122e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 1.2411e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 1.2905e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 22s 97ms/step - loss: 1.0724e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 22s 95ms/step - loss: 1.3372e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 9.4185e-05
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - loss: 1.0029e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 93ms/step - loss: 9.3807e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 8.4981e-05
# Saved model for Mahindra & Mahindra as models/M&M.NS_model.keras.
# -----------------------------------------------
# Training started for Maruti Suzuki.. Please wait..!!
# Epoch 1/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 20s 91ms/step - loss: 0.0070
# Epoch 2/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - loss: 2.3909e-04
# Epoch 3/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 2.1774e-04
# Epoch 4/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 92ms/step - loss: 1.9733e-04
# Epoch 5/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - loss: 1.9509e-04
# Epoch 6/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.9094e-04
# Epoch 7/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - loss: 1.8843e-04
# Epoch 8/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 92ms/step - loss: 1.6883e-04
# Epoch 9/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - loss: 1.8363e-04
# Epoch 10/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 15s 90ms/step - loss: 1.2889e-04
# Saved model for Maruti Suzuki as models/MARUTI.NS_model.keras.
# -----------------------------------------------
# Training started for Nestle India.. Please wait..!!
# Epoch 1/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 0.0152
# Epoch 2/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 1.5289e-04
# Epoch 3/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.4732e-04
# Epoch 4/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.2976e-04
# Epoch 5/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.2611e-04
# Epoch 6/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 1.3424e-04
# Epoch 7/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 1.1388e-04
# Epoch 8/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 1.2189e-04
# Epoch 9/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - loss: 1.4232e-04
# Epoch 10/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 1.1674e-04
# Saved model for Nestle India as models/NESTLEIND.NS_model.keras.
# -----------------------------------------------
# Training started for NTPC.. Please wait..!!
# Epoch 1/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 92ms/step - loss: 0.0090
# Epoch 2/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - loss: 1.6023e-04
# Epoch 3/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - loss: 1.5613e-04
# Epoch 4/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 1.8687e-04
# Epoch 5/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 1.5751e-04
# Epoch 6/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 92ms/step - loss: 1.5332e-04
# Epoch 7/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 1.5405e-04
# Epoch 8/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 1.3656e-04
# Epoch 9/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 1.3734e-04
# Epoch 10/10
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 1.4518e-04
# Saved model for NTPC as models/NTPC.NS_model.keras.
# -----------------------------------------------
# Training started for Oil and Natural Gas Corporation.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0080
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 2.0833e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - loss: 1.7879e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 94ms/step - loss: 1.6670e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - loss: 1.6588e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 21s 90ms/step - loss: 1.3732e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - loss: 1.3770e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - loss: 1.3540e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - loss: 1.1718e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 106ms/step - loss: 9.7682e-05
# Saved model for Oil and Natural Gas Corporation as models/ONGC.NS_model.keras.
# -----------------------------------------------
# Training started for Power Grid Corporation.. Please wait..!!
# Epoch 1/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - loss: 0.0101
# Epoch 2/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - loss: 1.5641e-04
# Epoch 3/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - loss: 1.5330e-04
# Epoch 4/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 1.5391e-04
# Epoch 5/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - loss: 1.5346e-04
# Epoch 6/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - loss: 1.5622e-04
# Epoch 7/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - loss: 1.4107e-04
# Epoch 8/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - loss: 1.5292e-04
# Epoch 9/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - loss: 1.2989e-04
# Epoch 10/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - loss: 1.4784e-04
# Saved model for Power Grid Corporation as models/POWERGRID.NS_model.keras.
# -----------------------------------------------
# Training started for Reliance Industries.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 30s 109ms/step - loss: 0.0098
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 42s 113ms/step - loss: 1.6453e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 109ms/step - loss: 1.8366e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - loss: 1.3378e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - loss: 1.5662e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 40s 106ms/step - loss: 1.1204e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 42s 110ms/step - loss: 1.0743e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 109ms/step - loss: 1.0331e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - loss: 9.3833e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 42s 110ms/step - loss: 9.1811e-05
# Saved model for Reliance Industries as models/RELIANCE.NS_model.keras.
# -----------------------------------------------
# Training started for State Bank of India.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 31s 110ms/step - loss: 0.0090
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 109ms/step - loss: 1.0600e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 40s 104ms/step - loss: 1.0066e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - loss: 9.3915e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - loss: 9.4852e-05
# Saved model for State Bank of India as models/SBIN.NS_model.keras.
# -----------------------------------------------
# Training started for Shree Cement.. Please wait..!!
# Epoch 1/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 25s 108ms/step - loss: 0.0160
# Epoch 2/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - loss: 4.1716e-04
# Epoch 3/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 3.4518e-04
# Epoch 4/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 3.1228e-04
# Epoch 5/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 105ms/step - loss: 3.0646e-04
# Epoch 6/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 3.2532e-04
# Epoch 7/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - loss: 2.3133e-04
# Epoch 8/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - loss: 2.6201e-04
# Epoch 9/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - loss: 2.3709e-04
# Epoch 10/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 1.8906e-04
# Saved model for Shree Cement as models/SHREECEM.NS_model.keras.
# -----------------------------------------------
# Training started for Sun Pharmaceutical.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 30s 108ms/step - loss: 0.0066
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 108ms/step - loss: 1.1204e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 109ms/step - loss: 1.1957e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 109ms/step - loss: 1.0765e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 43s 116ms/step - loss: 1.3948e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 108ms/step - loss: 8.7798e-05
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 108ms/step - loss: 1.1394e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 108ms/step - loss: 7.7891e-05
# Epoch 9/10
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 63s 109ms/step - loss: 1.0291e-04
# Epoch 7/10
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 29s 107ms/step - loss: 9.2282e-05
# Epoch 8/10
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 29s 107ms/step - loss: 8.7396e-05
# Epoch 9/10
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 41s 108ms/step - loss: 7.8460e-05
# Epoch 10/10
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 41s 107ms/step - loss: 6.2955e-05
# Saved model for Tata Motors as models/TATAMOTORS.NS_model.keras.
# -----------------------------------------------
# Training started for Tata Steel.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 30s 107ms/step - loss: 0.0033
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - loss: 2.1603e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 107ms/step - loss: 2.2467e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 108ms/step - loss: 1.5322e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - loss: 2.1410e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - loss: 1.5517e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 105ms/step - loss: 1.3169e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 106ms/step - loss: 1.9177e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - loss: 1.1519e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - loss: 1.3912e-04
# Saved model for Tata Steel as models/TATASTEEL.NS_model.keras.
# -----------------------------------------------
# Training started for Tech Mahindra.. Please wait..!!
# Epoch 1/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - loss: 0.0099
# Epoch 2/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 2.8269e-04
# Epoch 3/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - loss: 2.7162e-04
# Epoch 4/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - loss: 2.7162e-04
# Epoch 5/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - loss: 2.3379e-04
# Epoch 6/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - loss: 2.1471e-04
# Epoch 7/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - loss: 1.9005e-04
# Epoch 8/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - loss: 1.9033e-04
# Epoch 9/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - loss: 1.7714e-04
# Epoch 10/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 1.7123e-04
# Saved model for Tech Mahindra as models/TECHM.NS_model.keras.
# -----------------------------------------------
# Training started for Titan Company.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 31s 107ms/step - loss: 0.0054
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - loss: 1.4672e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - loss: 1.7360e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 23s 103ms/step - loss: 1.1060e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 23s 103ms/step - loss: 1.0871e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 105ms/step - loss: 1.2237e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - loss: 9.6059e-05
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - loss: 1.0985e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - loss: 8.1371e-05
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 23s 102ms/step - loss: 7.8279e-05
# Saved model for Titan Company as models/TITAN.NS_model.keras.
# -----------------------------------------------
# Training started for UltraTech Cement.. Please wait..!!
# Epoch 1/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 25s 108ms/step - loss: 0.0137
# Epoch 2/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 108ms/step - loss: 1.8041e-04
# Epoch 3/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - loss: 1.7681e-04
# Epoch 4/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - loss: 1.6071e-04
# Epoch 5/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 109ms/step - loss: 1.4831e-04
# Epoch 6/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 112ms/step - loss: 1.4999e-04
# Epoch 7/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 109ms/step - loss: 1.4278e-04
# Epoch 8/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - loss: 1.3461e-04
# Epoch 9/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 109ms/step - loss: 1.1979e-04
# Epoch 10/10
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - loss: 1.1251e-04
# Saved model for UltraTech Cement as models/ULTRACEMCO.NS_model.keras.
# -----------------------------------------------
# Training started for UPL.. Please wait..!!
# Epoch 1/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - loss: 0.0145
# Epoch 2/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - loss: 4.5968e-04
# Epoch 3/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - loss: 4.1228e-04
# Epoch 4/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 108ms/step - loss: 3.5977e-04
# Epoch 5/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - loss: 3.6137e-04
# Epoch 6/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 3.1251e-04
# Epoch 7/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 19s 109ms/step - loss: 2.9306e-04
# Epoch 8/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 2.5150e-04
# Epoch 9/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 2.3987e-04
# Epoch 10/10
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 2.4657e-04
# Saved model for UPL as models/UPL.NS_model.keras.
# -----------------------------------------------
# Training started for Wipro.. Please wait..!!
# Epoch 1/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 31s 109ms/step - loss: 0.0091
# Epoch 2/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 112ms/step - loss: 2.6068e-04
# Epoch 3/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 40s 105ms/step - loss: 2.2510e-04
# Epoch 4/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - loss: 1.6823e-04
# Epoch 5/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - loss: 1.9168e-04
# Epoch 6/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - loss: 1.3795e-04
# Epoch 7/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 107ms/step - loss: 1.4982e-04
# Epoch 8/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 41s 108ms/step - loss: 1.1637e-04
# Epoch 9/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 26s 113ms/step - loss: 1.0801e-04
# Epoch 10/10
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 25s 109ms/step - loss: 1.1973e-04
# Saved model for Wipro as models/WIPRO.NS_model.keras.
# -----------------------------------------------
